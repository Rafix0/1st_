# %%
# !pip install Flask

# %%
# !pip install flask_cors

# %%
import requests
import bs4
import urllib

# %%
# !pip install urllib.request
# Out:
# ERROR: Could not find a version that satisfies the requirement urllib.request (from versions: none)
# ERROR: No matching distribution found for urllib.request

# %%
# !pip install urlopen
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for urlopen: filename=urlopen-1.0.0-py3-none-any.whl size=1383 sha256=257be08d7609d36f46beff5256a1372683e3b70c06be42bb81466023df98e5ab
#   Stored in directory: c:\users\rafi\appdata\local\pip\cache\wheels\59\6a\b1\985d91ea20feea120e71e88fc5b085c5d57297a80645eb7e8c
# Successfully built urlopen
# ...

# %%
from flask import Flask, render_template, request,jsonify
from flask_cors import CORS,cross_origin
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# %%
flipkart_url = "https://www.flipkart.com/search?q=" + 'iphone7'

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone7'

# %%
uClient = uReq(flipkart_url)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# D:\setup software\anaconda\anaconda\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1345             try:
# -> 1346                 h.request(req.get_method(), req.selector, req.data, headers,
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#
# D:\setup software\anaconda\anaconda\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1284         """Send a complete request to the server."""
# -> 1285         self._send_request(method, url, body, headers, encode_chunked)
#    1286
#
# D:\setup software\anaconda\anaconda\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1330             body = _encode(body, 'body')
# -> 1331         self.endheaders(body, encode_chunked=encode_chunked)
# ...

# %%
import ssl
from urllib.request import urlopen

# Disable SSL certificate verification (not recommended for production code)
context = ssl._create_unverified_context()

flipkart_url = "https://www.flipkart.com/search?q=iphone7"

# Use the unverified context when opening the URL
uClient = urlopen(flipkart_url, context=context)
import time

# Add a delay of, for example, 2 seconds between requests
time.sleep(2)

# %%
uClient

# %%
 flipkartPage = uClient.read()

# %%
flipkartPage
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.615ed9.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
uClient.close()

# %%
flipkart_html = bs(flipkartPage, "html.parser")
flipkart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
 bigboxes = flipkart_html.findAll("div", {"class": "_1AtVbE col-12-12"})

# %%
del bigboxes[0:3]

# %%
box = bigboxes[0]

# %%
box
# Out:
# <div class="_1AtVbE col-12-12"><div class="_13oc-S"><div data-id="MOBEMK62QFEVEPP4" style="width:100%"><div class="_2kHMtA"><a class="_1fQZEK" href="/apple-iphone-7-plus-gold-128-gb/p/itmemn5wz3hm6gjt?pid=MOBEMK62QFEVEPP4&amp;lid=LSTMOBEMK62QFEVEPP44S5PQP&amp;marketplace=FLIPKART&amp;q=iphone7&amp;store=tyy%2F4io&amp;srno=s_1_1&amp;otracker=search&amp;fm=organic&amp;iid=e41a317f-3ece-4508-9c3e-e7e60f7b9a59.MOBEMK62QFEVEPP4.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=1qv361v0ds0000001704267533017&amp;qH=c848b7081ba96a14" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="APPLE iPhone 7 Plus (Gold, 128 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/k13w4280/mobile/p/p/4/apple-iphone-7-plus-mn4q2hn-a-original-imafkqfhjzsvghb8.jpeg?q=70"/></div></div><div class="_3G6awp"><span class="u05wbu">Coming Soon</span></div></div><div class="_3wLduG"></div><div
# ...

# %%
len(bigboxes)
# Out:
# 27

# %%
productLink = "https://www.flipkart.com"+ box.div.div.div.a['href']

# %%
box.div.div.div.a['href']
# Out:
# '/apple-iphone-7-plus-gold-128-gb/p/itmemn5wz3hm6gjt?pid=MOBEMK62QFEVEPP4&lid=LSTMOBEMK62QFEVEPP44S5PQP&marketplace=FLIPKART&q=iphone7&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=e41a317f-3ece-4508-9c3e-e7e60f7b9a59.MOBEMK62QFEVEPP4.SEARCH&ppt=None&ppn=None&ssid=1qv361v0ds0000001704267533017&qH=c848b7081ba96a14'

# %%
prodRes = requests.get(productLink)

# %%
prodRes.encoding= 'utf-8'

# %%
prodRes
# Out:
# <Response [200]>

# %%
prod_html = bs(prodRes.text, "html.parser")
print(prod_html)
# Out:
# <!DOCTYPE html>
# ...

# %%
commentboxes = prod_html.find_all('div', {'class': "_16PBlm"})

# %%
len(commentboxes)
# Out:
# 11

# %%
commentboxes[0]
# Out:
# <div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Simply awesome</p></div><div class="row"><div class="t-ZTKy"><div><div class="">My first iPhone <br/>Super performance</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202003/blobio-imr-202003_cd83580918734596b7496831512d728d.jpeg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div></div><div class="row _3n8db9"><div class="row"><p class="_2sc7ZR _2V5EHH">Flipkart Customer</p><svg class="_2a1p_T" height="14" viewbox="0 0 12 12" width="14" xmlns="http://www.w3.org/2000/svg"><g><circle cx="6" cy="6" fill="#878787" r="6"></circle><path d="M3 6l2 2 4-4" fill="#878787" stroke="#FFF" stroke-width="1.5"></path></g></svg><p class="_2mcZGG" id="review
# ...

# %%
name = commentboxes[0].div.div.find_all('p', {'class': '_2sc7ZR _2V5EHH'})[0].text

# %%
name
# Out:
# 'Flipkart Customer'

# %%
rating = commentboxes[0].div.div.div.div.text

# %%
rating
# Out:
# '5'

# %%
commentHead = commentboxes[0].div.div.div.p.text

# %%
commentHead
# Out:
# 'Simply awesome'

# %%
comtag = commentboxes[0].div.div.find_all('div', {'class': ''})

# %%
comtag
# Out:
# [<div><div class="">My first iPhone <br/>Super performance</div><span class="_1H-bmy"><span>READ MORE</span></span></div>,
#  <div class="">My first iPhone <br/>Super performance</div>,
#  <div></div>]

# %%
custComment = comtag[0].div.text

# %%
custComment
# Out:
# 'My first iPhone Super performance'
